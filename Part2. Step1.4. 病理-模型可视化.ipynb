# %% [markdown]
# ## What可视化
#
# 2D Grand CAM可视化模块

# %% [markdown]
# ## 打印可视化界面

# %%
from onekey_algo.datasets.image_loader import default_loader
from onekey_algo.custom.components.comp2 import show_cam_on_image
import torch
import os
import random

from onekey_algo.custom.components.comp2 import extract, init_from_model, init_from_onekey
from onekey_algo.utils.MultiProcess import MultiProcess
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

import monai
from glob import glob
import matplotlib.pyplot as plt
import pandas as pd

samples = glob(r'E:\20240601-BiQiu\Pathomics\patches_norm/*.jpg') + glob(r'E:\20240601-BiQiu\Pathomics\patches_norm/*.jpg')
model_root = r'D:\20230713-BiQiu\Pathology\models\inception_v3'
random.shuffle(samples)
def viz_sample(samples, thread_id):
    model, transformer, device = init_from_onekey(os.path.join(root, r'viz'))
    for n, m in model.named_modules():
        print('Feature name:', n, "|| Module:", m)
    target_layer = "Mixed_7c.branch_pool.conv"
    gradcam = monai.visualize.GradCAM(nn_module=model, target_layers=target_layer)

    random.shuffle(samples)
    viz_dir = r'D:\20230713-BiQiu\Pathology\models\inception_v3\Grad-CAM'
    os.makedirs(viz_dir, exist_ok=True)
    for sample in samples:
        img = default_loader(sample)
        sample_ = transformer(img)
        sample_  = sample_.view(1, *sample_.size()).to(device)
        res_cam = gradcam(x=sample_, class_idx=None)
        fig, axes = plt.subplots(1, 2, figsize=(20, 10), facecolor='white')
    #     axes[0].imshow(-res_cam[0][0].cpu(), cmap='jet')
        axes[0].imshow(img.resize(sample_.size()[2:]))
        axes[0].axis('off')
    #     plt.savefig(f"viz/{os.path.basename(sample).replace('.png', '_se.png')}", bbox_inches = 'tight')
    #     plt.show()
    #     plt.figure(figsize=(10, 10))
    #     plt.axis('off')
        imshow = axes[1].imshow(show_cam_on_image(img.resize(sample_.size()[2:]), -res_cam[0][0].cpu(), use_rgb=True, reverse=False), 
                                cmap='jet')
        axes[1].axis('off')
        cax = fig.add_axes([0.92, 0.15, 0.02, axes[1].get_position().height]) 
        plt.colorbar(imshow, cax=cax)
        plt.savefig(f'{viz_dir}/{os.path.basename(sample)}', bbox_inches = 'tight')
        plt.close()
viz_sample(samples, thread_id=1)
# MultiProcess(func=viz_sample, samples=samples, num_process=1).run()
# Out:
# Feature name:  || Module: Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=2, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=2, bias=True)
# )
# Feature name: Conv2d_1a_3x3 || Module: BasicConv2d(
#   (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Conv2d_1a_3x3.conv || Module: Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
# Feature name: Conv2d_1a_3x3.bn || Module: BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Conv2d_2a_3x3 || Module: BasicConv2d(
#   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Conv2d_2a_3x3.conv || Module: Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
# Feature name: Conv2d_2a_3x3.bn || Module: BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Conv2d_2b_3x3 || Module: BasicConv2d(
#   (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Conv2d_2b_3x3.conv || Module: Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Conv2d_2b_3x3.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: maxpool1 || Module: MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# Feature name: Conv2d_3b_1x1 || Module: BasicConv2d(
#   (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Conv2d_3b_1x1.conv || Module: Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Conv2d_3b_1x1.bn || Module: BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Conv2d_4a_3x3 || Module: BasicConv2d(
#   (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Conv2d_4a_3x3.conv || Module: Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
# Feature name: Conv2d_4a_3x3.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: maxpool2 || Module: MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
# Feature name: Mixed_5b || Module: InceptionA(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_1): BasicConv2d(
#     (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_2): BasicConv2d(
#     (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3): BasicConv2d(
#     (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_5b.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch1x1.conv || Module: Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5b.branch1x1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch5x5_1 || Module: BasicConv2d(
#   (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch5x5_1.conv || Module: Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5b.branch5x5_1.bn || Module: BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch5x5_2 || Module: BasicConv2d(
#   (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch5x5_2.conv || Module: Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
# Feature name: Mixed_5b.branch5x5_2.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch3x3dbl_1.conv || Module: Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5b.branch3x3dbl_1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch3x3dbl_2.conv || Module: Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5b.branch3x3dbl_2.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch3x3dbl_3 || Module: BasicConv2d(
#   (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch3x3dbl_3.conv || Module: Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5b.branch3x3dbl_3.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5b.branch_pool || Module: BasicConv2d(
#   (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5b.branch_pool.conv || Module: Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5b.branch_pool.bn || Module: BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c || Module: InceptionA(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_1): BasicConv2d(
#     (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_2): BasicConv2d(
#     (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3): BasicConv2d(
#     (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_5c.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch1x1.conv || Module: Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5c.branch1x1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch5x5_1 || Module: BasicConv2d(
#   (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch5x5_1.conv || Module: Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5c.branch5x5_1.bn || Module: BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch5x5_2 || Module: BasicConv2d(
#   (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch5x5_2.conv || Module: Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
# Feature name: Mixed_5c.branch5x5_2.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch3x3dbl_1.conv || Module: Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5c.branch3x3dbl_1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch3x3dbl_2.conv || Module: Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5c.branch3x3dbl_2.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch3x3dbl_3 || Module: BasicConv2d(
#   (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch3x3dbl_3.conv || Module: Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5c.branch3x3dbl_3.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5c.branch_pool || Module: BasicConv2d(
#   (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5c.branch_pool.conv || Module: Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5c.branch_pool.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d || Module: InceptionA(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_1): BasicConv2d(
#     (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch5x5_2): BasicConv2d(
#     (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3): BasicConv2d(
#     (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_5d.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch1x1.conv || Module: Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5d.branch1x1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch5x5_1 || Module: BasicConv2d(
#   (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch5x5_1.conv || Module: Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5d.branch5x5_1.bn || Module: BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch5x5_2 || Module: BasicConv2d(
#   (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch5x5_2.conv || Module: Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
# Feature name: Mixed_5d.branch5x5_2.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch3x3dbl_1.conv || Module: Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5d.branch3x3dbl_1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch3x3dbl_2.conv || Module: Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5d.branch3x3dbl_2.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch3x3dbl_3 || Module: BasicConv2d(
#   (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch3x3dbl_3.conv || Module: Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_5d.branch3x3dbl_3.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_5d.branch_pool || Module: BasicConv2d(
#   (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_5d.branch_pool.conv || Module: Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_5d.branch_pool.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6a || Module: InceptionB(
#   (branch3x3): BasicConv2d(
#     (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3): BasicConv2d(
#     (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_6a.branch3x3 || Module: BasicConv2d(
#   (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6a.branch3x3.conv || Module: Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
# Feature name: Mixed_6a.branch3x3.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6a.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6a.branch3x3dbl_1.conv || Module: Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_6a.branch3x3dbl_1.bn || Module: BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6a.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6a.branch3x3dbl_2.conv || Module: Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_6a.branch3x3dbl_2.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6a.branch3x3dbl_3 || Module: BasicConv2d(
#   (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6a.branch3x3dbl_3.conv || Module: Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
# Feature name: Mixed_6a.branch3x3dbl_3.bn || Module: BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b || Module: InceptionC(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7_1): BasicConv2d(
#     (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7_2): BasicConv2d(
#     (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7_3): BasicConv2d(
#     (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7dbl_1): BasicConv2d(
#     (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7dbl_2): BasicConv2d(
#     (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7dbl_3): BasicConv2d(
#     (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7dbl_4): BasicConv2d(
#     (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#     (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch7x7dbl_5): BasicConv2d(
#     (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_6b.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch1x1.conv || Module: Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_6b.branch1x1.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7_1 || Module: BasicConv2d(
#   (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7_1.conv || Module: Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_6b.branch7x7_1.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7_2 || Module: BasicConv2d(
#   (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7_2.conv || Module: Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
# Feature name: Mixed_6b.branch7x7_2.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7_3 || Module: BasicConv2d(
#   (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7_3.conv || Module: Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
# Feature name: Mixed_6b.branch7x7_3.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7dbl_1.conv || Module: Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_6b.branch7x7dbl_1.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7dbl_2.conv || Module: Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
# Feature name: Mixed_6b.branch7x7dbl_2.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7dbl_3 || Module: BasicConv2d(
#   (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7dbl_3.conv || Module: Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
# Feature name: Mixed_6b.branch7x7dbl_3.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7dbl_4 || Module: BasicConv2d(
#   (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#   (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7dbl_4.conv || Module: Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
# Feature name: Mixed_6b.branch7x7dbl_4.bn || Module: BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_6b.branch7x7dbl_5 || Module: BasicConv2d(
#   (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_6b.branch7x7dbl_5.conv || Module: Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
# ...
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_7a.branch3x3_1 || Module: BasicConv2d(
#   (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch3x3_1.conv || Module: Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7a.branch3x3_1.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7a.branch3x3_2 || Module: BasicConv2d(
#   (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch3x3_2.conv || Module: Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
# Feature name: Mixed_7a.branch3x3_2.bn || Module: BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7a.branch7x7x3_1 || Module: BasicConv2d(
#   (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch7x7x3_1.conv || Module: Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7a.branch7x7x3_1.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7a.branch7x7x3_2 || Module: BasicConv2d(
#   (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch7x7x3_2.conv || Module: Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
# Feature name: Mixed_7a.branch7x7x3_2.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7a.branch7x7x3_3 || Module: BasicConv2d(
#   (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch7x7x3_3.conv || Module: Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
# Feature name: Mixed_7a.branch7x7x3_3.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7a.branch7x7x3_4 || Module: BasicConv2d(
#   (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7a.branch7x7x3_4.conv || Module: Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
# Feature name: Mixed_7a.branch7x7x3_4.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b || Module: InceptionE(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_1): BasicConv2d(
#     (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_2a): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_2b): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3a): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3b): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_7b.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch1x1.conv || Module: Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7b.branch1x1.bn || Module: BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3_1 || Module: BasicConv2d(
#   (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3_1.conv || Module: Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7b.branch3x3_1.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3_2a || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3_2a.conv || Module: Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
# Feature name: Mixed_7b.branch3x3_2a.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3_2b || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3_2b.conv || Module: Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
# Feature name: Mixed_7b.branch3x3_2b.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3dbl_1.conv || Module: Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7b.branch3x3dbl_1.bn || Module: BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3dbl_2.conv || Module: Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_7b.branch3x3dbl_2.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3dbl_3a || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3dbl_3a.conv || Module: Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
# Feature name: Mixed_7b.branch3x3dbl_3a.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch3x3dbl_3b || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch3x3dbl_3b.conv || Module: Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
# Feature name: Mixed_7b.branch3x3dbl_3b.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7b.branch_pool || Module: BasicConv2d(
#   (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7b.branch_pool.conv || Module: Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7b.branch_pool.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c || Module: InceptionE(
#   (branch1x1): BasicConv2d(
#     (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_1): BasicConv2d(
#     (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_2a): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3_2b): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_1): BasicConv2d(
#     (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_2): BasicConv2d(
#     (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3a): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch3x3dbl_3b): BasicConv2d(
#     (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#     (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (branch_pool): BasicConv2d(
#     (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
# Feature name: Mixed_7c.branch1x1 || Module: BasicConv2d(
#   (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch1x1.conv || Module: Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7c.branch1x1.bn || Module: BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3_1 || Module: BasicConv2d(
#   (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3_1.conv || Module: Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7c.branch3x3_1.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3_2a || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3_2a.conv || Module: Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
# Feature name: Mixed_7c.branch3x3_2a.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3_2b || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3_2b.conv || Module: Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
# Feature name: Mixed_7c.branch3x3_2b.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3dbl_1 || Module: BasicConv2d(
#   (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3dbl_1.conv || Module: Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7c.branch3x3dbl_1.bn || Module: BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3dbl_2 || Module: BasicConv2d(
#   (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3dbl_2.conv || Module: Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# Feature name: Mixed_7c.branch3x3dbl_2.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3dbl_3a || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3dbl_3a.conv || Module: Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
# Feature name: Mixed_7c.branch3x3dbl_3a.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch3x3dbl_3b || Module: BasicConv2d(
#   (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#   (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch3x3dbl_3b.conv || Module: Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
# Feature name: Mixed_7c.branch3x3dbl_3b.bn || Module: BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: Mixed_7c.branch_pool || Module: BasicConv2d(
#   (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# )
# Feature name: Mixed_7c.branch_pool.conv || Module: Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# Feature name: Mixed_7c.branch_pool.bn || Module: BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
# Feature name: avgpool || Module: AdaptiveAvgPool2d(output_size=(1, 1))
# Feature name: dropout || Module: Dropout(p=0.5, inplace=False)
# Feature name: fc || Module: Linear(in_features=2048, out_features=2, bias=True)
